# %% [markdown]
# **Import packages**

# %%
# !pip install pytictoc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytictoc
#   Downloading pytictoc-1.5.2-py2.py3-none-any.whl (4.0 kB)
# Installing collected packages: pytictoc
# Successfully installed pytictoc-1.5.2

# %%
import random
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pytictoc import TicToc
from sklearn.model_selection import train_test_split
warnings.filterwarnings( "ignore" )

# %% [markdown]
# **Load the dataset**

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# ((50000, 32, 32, 3), (50000,), (10000, 32, 32, 3), (10000,))

# %% [markdown]
# **Create helper functions**

# %%
def plot_sample_image(X, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(X[index])
    classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
    plt.xlabel('Image Label: {}'.format(classes[y[index]]))

def classification_results(X_test,y_test,y_pred_classes):
  from sklearn.metrics import confusion_matrix , classification_report
  import seaborn as sn

  cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_classes)
  plt.figure(figsize = (7,5))
  sn.heatmap(cm, annot=True, fmt='d', cmap='Greens')
  plt.xlabel('Predicted');
  plt.ylabel('Truth');

  print("Classification Report: \n", classification_report(y_test, y_pred_classes))

def plot_fitting_history(history,filename,dpi):
  epochs = len(history.history['loss'])
  epoch_data = np.arange(1,epochs+1)
  plt.plot(epoch_data,history.history['loss'],'o-')
  plt.ylabel('Loss')
  plt.xlabel('Epoch sequence' )
  if epochs <= 60: plt.xticks(np.arange(0, epochs + 1, step=5))
  else: plt.xticks(np.arange(0, epochs + 1, step=20))
  if 'val_loss' in history.history.keys():
    plt.plot(epoch_data,history.history['val_loss'],'o--')
    plt.legend(['Training','Validation'])
  else:
    plt.legend(['Training'])
  plt.savefig(filename, dpi=dpi)
  plt.show()

# %% [markdown]
# **Plot sample image**

# %%
plot_sample_image(X_train, y_train, np.random.randint(100))

# %% [markdown]
# **Normalize the input data**

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # Linear Classifier

# %% [markdown]
# **Fit the model**

# %%
import random
import tensorflow as tf
seed = 42
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

C_linear = models.Sequential([
        layers.Flatten(input_shape=X_train.shape[1:]),
        layers.Dense(10, activation='softmax'),  
    ])

C_linear.summary()

learning_rate =  0.0001
C_linear.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

t_linear = TicToc()
t_linear.tic()
early_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
history_C_linear = C_linear.fit(X_train, y_train, epochs=200, batch_size=32,
            validation_split = 0.1, callbacks = early_callbacks, verbose=1)
t_linear.toc()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 10)                30730
#
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 1407/1407 [==============================] - 10s 3ms/step - loss: 1.9914 - accuracy: 0.2918 - val_loss: 1.9024 - val_accuracy: 0.3424
# Epoch 2/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.8537 - accuracy: 0.3541 - val_loss: 1.8396 - val_accuracy: 0.3632
# Epoch 3/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.8163 - accuracy: 0.3669 - val_loss: 1.8231 - val_accuracy: 0.3750
# Epoch 4/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7963 - accuracy: 0.3776 - val_loss: 1.8188 - val_accuracy: 0.3626
# Epoch 5/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7824 - accuracy: 0.3819 - val_loss: 1.7999 - val_accuracy: 0.3736
# Epoch 6/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7687 - accuracy: 0.3890 - val_loss: 1.7997 - val_accuracy: 0.3762
# Epoch 7/200
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.7596 - accuracy: 0.3942 - val_loss: 1.8001 - val_accuracy: 0.3696
# Epoch 8/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7525 - accuracy: 0.3971 - val_loss: 1.7940 - val_accuracy: 0.3768
# Epoch 9/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7480 - accuracy: 0.3980 - val_loss: 1.7889 - val_accuracy: 0.3730
# Epoch 10/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7421 - accuracy: 0.3997 - val_loss: 1.7708 - val_accuracy: 0.3918
# Epoch 11/200
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.7363 - accuracy: 0.4048 - val_loss: 1.7711 - val_accuracy: 0.3876
# Epoch 12/200
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.7315 - accuracy: 0.4052 - val_loss: 1.7625 - val_accuracy: 0.3944
# Epoch 13/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7279 - accuracy: 0.4056 - val_loss: 1.7752 - val_accuracy: 0.3802
# Epoch 14/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7241 - accuracy: 0.4075 - val_loss: 1.7609 - val_accuracy: 0.3944
# Epoch 15/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7197 - accuracy: 0.4097 - val_loss: 1.7733 - val_accuracy: 0.3776
# Epoch 16/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7162 - accuracy: 0.4130 - val_loss: 1.7618 - val_accuracy: 0.3972
# Epoch 17/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7128 - accuracy: 0.4140 - val_loss: 1.7557 - val_accuracy: 0.3984
# Epoch 18/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7113 - accuracy: 0.4138 - val_loss: 1.7613 - val_accuracy: 0.3958
# Epoch 19/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7085 - accuracy: 0.4153 - val_loss: 1.7547 - val_accuracy: 0.3980
# Epoch 20/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7069 - accuracy: 0.4161 - val_loss: 1.7564 - val_accuracy: 0.3894
# Epoch 21/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.7032 - accuracy: 0.4172 - val_loss: 1.7629 - val_accuracy: 0.3884
# Epoch 22/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.7025 - accuracy: 0.4161 - val_loss: 1.7442 - val_accuracy: 0.3946
# Epoch 23/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6993 - accuracy: 0.4186 - val_loss: 1.7562 - val_accuracy: 0.3912
# Epoch 24/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6981 - accuracy: 0.4195 - val_loss: 1.7609 - val_accuracy: 0.3926
# Epoch 25/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6953 - accuracy: 0.4195 - val_loss: 1.7701 - val_accuracy: 0.3904
# Epoch 26/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6934 - accuracy: 0.4237 - val_loss: 1.7489 - val_accuracy: 0.3992
# Epoch 27/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6931 - accuracy: 0.4208 - val_loss: 1.7450 - val_accuracy: 0.3996
# Epoch 28/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6897 - accuracy: 0.4223 - val_loss: 1.7513 - val_accuracy: 0.3994
# Epoch 29/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6895 - accuracy: 0.4240 - val_loss: 1.7553 - val_accuracy: 0.3894
# Epoch 30/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6876 - accuracy: 0.4226 - val_loss: 1.7564 - val_accuracy: 0.4002
# Epoch 31/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6863 - accuracy: 0.4234 - val_loss: 1.7551 - val_accuracy: 0.4048
# Epoch 32/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6848 - accuracy: 0.4244 - val_loss: 1.7446 - val_accuracy: 0.3954
# Epoch 33/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6840 - accuracy: 0.4238 - val_loss: 1.7660 - val_accuracy: 0.3810
# Epoch 34/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6818 - accuracy: 0.4263 - val_loss: 1.7473 - val_accuracy: 0.4020
# Epoch 35/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6824 - accuracy: 0.4251 - val_loss: 1.7439 - val_accuracy: 0.3994
# Epoch 36/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6785 - accuracy: 0.4260 - val_loss: 1.7461 - val_accuracy: 0.3998
# Epoch 37/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6794 - accuracy: 0.4273 - val_loss: 1.7393 - val_accuracy: 0.4006
# Epoch 38/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6780 - accuracy: 0.4263 - val_loss: 1.7498 - val_accuracy: 0.4006
# Epoch 39/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6761 - accuracy: 0.4292 - val_loss: 1.7411 - val_accuracy: 0.4016
# Epoch 40/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6753 - accuracy: 0.4281 - val_loss: 1.7502 - val_accuracy: 0.3998
# Epoch 41/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6745 - accuracy: 0.4282 - val_loss: 1.7452 - val_accuracy: 0.4008
# Epoch 42/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6740 - accuracy: 0.4305 - val_loss: 1.7347 - val_accuracy: 0.4072
# Epoch 43/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.
200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6470 - accuracy: 0.4406 - val_loss: 1.7552 - val_accuracy: 0.3968
# Epoch 77/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6472 - accuracy: 0.4401 - val_loss: 1.7397 - val_accuracy: 0.4010
# Epoch 78/200
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.6469 - accuracy: 0.4400 - val_loss: 1.7388 - val_accuracy: 0.4016
# Epoch 79/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6459 - accuracy: 0.4413 - val_loss: 1.7451 - val_accuracy: 0.3940
# Epoch 80/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6455 - accuracy: 0.4422 - val_loss: 1.7439 - val_accuracy: 0.4024
# Epoch 81/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6447 - accuracy: 0.4422 - val_loss: 1.7451 - val_accuracy: 0.4098
# Epoch 82/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6468 - accuracy: 0.4399 - val_loss: 1.7450 - val_accuracy: 0.4034
# Epoch 83/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6441 - accuracy: 0.4414 - val_loss: 1.7386 - val_accuracy: 0.4118
# Epoch 84/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6444 - accuracy: 0.4427 - val_loss: 1.7413 - val_accuracy: 0.4020
# Epoch 85/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6444 - accuracy: 0.4401 - val_loss: 1.7419 - val_accuracy: 0.4020
# Epoch 86/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6429 - accuracy: 0.4419 - val_loss: 1.7407 - val_accuracy: 0.4032
# Epoch 87/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6428 - accuracy: 0.4420 - val_loss: 1.7418 - val_accuracy: 0.4110
# Epoch 88/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6431 - accuracy: 0.4419 - val_loss: 1.7482 - val_accuracy: 0.4006
# Epoch 89/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6416 - accuracy: 0.4423 - val_loss: 1.7493 - val_accuracy: 0.3966
# Epoch 90/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6417 - accuracy: 0.4420 - val_loss: 1.7574 - val_accuracy: 0.3908
# Epoch 91/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6412 - accuracy: 0.4439 - val_loss: 1.7404 - val_accuracy: 0.4112
# Epoch 92/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6405 - accuracy: 0.4437 - val_loss: 1.7353 - val_accuracy: 0.4096
# Epoch 93/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6395 - accuracy: 0.4438 - val_loss: 1.7373 - val_accuracy: 0.4114
# Epoch 94/200
# 1407/1407 [==============================] - 4s 3ms/step - loss: 1.6398 - accuracy: 0.4433 - val_loss: 1.7350 - val_accuracy: 0.4088
# Epoch 95/200
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6402 - accuracy: 0.4439 - val_loss: 1.7355 - val_accuracy: 0.4050
# Elapsed time is 425.855917 seconds.

# %%
C_linear.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7261 - accuracy: 0.4032
# [1.7261289358139038, 0.4032000005245209]

# %%
filename = 'Training history CIFAR10 [Linear]'+'.png'
plot_fitting_history(history_C_linear, filename, dpi = 100)

# %% [markdown]
# **Report classification performance & plot confusion matrix**

# %%
y_pred = C_linear.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]
classification_results(X_test,y_test,y_pred_classes)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.45      0.49      0.47      1000
#            1       0.56      0.37      0.45      1000
#            2       0.33      0.26      0.29      1000
#            3       0.27      0.36      0.31      1000
#            4       0.41      0.21      0.28      1000
#            5       0.35      0.32      0.33      1000
#            6       0.40      0.48      0.44      1000
#            7       0.44      0.49      0.46      1000
#            8       0.49      0.51      0.50      1000
#            9       0.40      0.55      0.46      1000
#
#     accuracy                           0.40     10000
#    macro avg       0.41      0.40      0.40     10000
# weighted avg       0.41      0.40      0.40     10000

# %%
C_linear.save('Linear_CIFAR10.h5')

# %%
from keras.models import load_model
Linear_CIFAR10 = load_model('Linear_CIFAR10.h5')

# %%
Linear_CIFAR10.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7261 - accuracy: 0.4032
# [1.7261289358139038, 0.4032000005245209]
