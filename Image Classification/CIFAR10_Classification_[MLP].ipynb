# %% [markdown]
# **Import packages**

# %%
# !pip install pytictoc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytictoc
#   Downloading pytictoc-1.5.2-py2.py3-none-any.whl (4.0 kB)
# Installing collected packages: pytictoc
# Successfully installed pytictoc-1.5.2

# %%
import random
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pytictoc import TicToc
from sklearn.model_selection import train_test_split
warnings.filterwarnings( "ignore" )

# %% [markdown]
# **Load the dataset**

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# ((50000, 32, 32, 3), (50000,), (10000, 32, 32, 3), (10000,))

# %% [markdown]
# **Create helper functions**

# %%
def plot_sample_image(X, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(X[index])
    classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
    plt.xlabel('Image Label: {}'.format(classes[y[index]]))

def classification_results(X_test,y_test,y_pred_classes):
  from sklearn.metrics import confusion_matrix , classification_report
  import seaborn as sn

  cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_classes)
  plt.figure(figsize = (7,5))
  sn.heatmap(cm, annot=True, fmt='d', cmap='Greens')
  plt.xlabel('Predicted');
  plt.ylabel('Truth');

  print("Classification Report: \n", classification_report(y_test, y_pred_classes))

def plot_fitting_history(history,filename,dpi):
  epochs = len(history.history['loss'])
  epoch_data = np.arange(1,epochs+1)
  plt.plot(epoch_data,history.history['loss'],'o-')
  plt.ylabel('Loss')
  plt.xlabel('Epoch sequence' )
  if epochs <= 60: plt.xticks(np.arange(0, epochs + 1, step=5))
  else: plt.xticks(np.arange(0, epochs + 1, step=20))
  if 'val_loss' in history.history.keys():
    plt.plot(epoch_data,history.history['val_loss'],'o--')
    plt.legend(['Training','Validation'])
  else:
    plt.legend(['Training'])
  plt.savefig(filename, dpi=dpi)
  plt.show()

# %% [markdown]
# **Plot sample image**

# %%
plot_sample_image(X_train, y_train, np.random.randint(100))

# %% [markdown]
# **Normalize the input data**

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # MLP (multi-layer perceptron) classifier

# %% [markdown]
# **Fit the model**

# %%
import random
import tensorflow as tf
seed = 42
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

C_MLP = models.Sequential([
        layers.Flatten(input_shape=X_train.shape[1:]),
        layers.Dense(1024, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(1024, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')    
    ])

C_MLP.summary()

learning_rate =  0.0001
C_MLP.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

t_MLP = TicToc()
t_MLP.tic()
early_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
history_C_MLP = C_MLP.fit(X_train, y_train, epochs=200, batch_size=32,
            validation_split = 0.1, callbacks = early_callbacks, verbose=1)
t_MLP.toc()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 1024)              3146752
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 1024)              525312
#
#  batch_normalization_4 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 4,746,762
# Trainable params: 4,739,594
# Non-trainable params: 7,168
# _________________________________________________________________
# Epoch 1/200
# 1407/1407 [==============================] - 23s 8ms/step - loss: 3.0020 - accuracy: 0.1609 - val_loss: 1.9443 - val_accuracy: 0.2846
# Epoch 2/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 2.5154 - accuracy: 0.2050 - val_loss: 1.9126 - val_accuracy: 0.3140
# Epoch 3/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 2.2949 - accuracy: 0.2331 - val_loss: 1.8541 - val_accuracy: 0.3296
# Epoch 4/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 2.1421 - accuracy: 0.2519 - val_loss: 1.8253 - val_accuracy: 0.3444
# Epoch 5/200
# 1407/1407 [==============================] - 13s 9ms/step - loss: 2.0239 - accuracy: 0.2797 - val_loss: 1.8107 - val_accuracy: 0.3494
# Epoch 6/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.9465 - accuracy: 0.3015 - val_loss: 1.7697 - val_accuracy: 0.3514
# Epoch 7/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.8845 - accuracy: 0.3181 - val_loss: 1.7818 - val_accuracy: 0.3570
# Epoch 8/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.8488 - accuracy: 0.3355 - val_loss: 1.6815 - val_accuracy: 0.4000
# Epoch 9/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.8149 - accuracy: 0.3437 - val_loss: 1.6993 - val_accuracy: 0.3854
# Epoch 10/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7971 - accuracy: 0.3524 - val_loss: 1.6712 - val_accuracy: 0.4048
# Epoch 11/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7770 - accuracy: 0.3585 - val_loss: 1.6797 - val_accuracy: 0.4064
# Epoch 12/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7649 - accuracy: 0.3693 - val_loss: 1.6848 - val_accuracy: 0.4030
# Epoch 13/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7394 - accuracy: 0.3762 - val_loss: 1.6290 - val_accuracy: 0.4304
# Epoch 14/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.7337 - accuracy: 0.3779 - val_loss: 1.7623 - val_accuracy: 0.3826
# Epoch 15/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7364 - accuracy: 0.3804 - val_loss: 1.5949 - val_accuracy: 0.4352
# Epoch 16/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.7263 - accuracy: 0.3822 - val_loss: 1.6128 - val_accuracy: 0.4352
# Epoch 17/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.7120 - accuracy: 0.3878 - val_loss: 1.5853 - val_accuracy: 0.4418
# Epoch 18/200
# 1407/1407 [==============================] - 12s 9ms/step - loss: 1.7056 - accuracy: 0.3905 - val_loss: 1.5846 - val_accuracy: 0.4408
# Epoch 19/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6964 - accuracy: 0.3942 - val_loss: 1.5771 - val_accuracy: 0.4438
# Epoch 20/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6885 - accuracy: 0.3978 - val_loss: 1.5465 - val_accuracy: 0.4496
# Epoch 21/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6859 - accuracy: 0.3960 - val_loss: 1.5447 - val_accuracy: 0.4568
# Epoch 22/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6855 - accuracy: 0.3983 - val_loss: 1.5549 - val_accuracy: 0.4488
# Epoch 23/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6914 - accuracy: 0.3975 - val_loss: 1.6028 - val_accuracy: 0.4332
# Epoch 24/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6769 - accuracy: 0.4007 - val_loss: 1.5708 - val_accuracy: 0.4490
# Epoch 25/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6654 - accuracy: 0.4058 - val_loss: 1.5428 - val_accuracy: 0.4594
# Epoch 26/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6624 - accuracy: 0.4087 - val_loss: 1.5332 - val_accuracy: 0.4620
# Epoch 27/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6651 - accuracy: 0.4060 - val_loss: 1.5883 - val_accuracy: 0.4408
# Epoch 28/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6635 - accuracy: 0.4089 - val_loss: 1.5039 - val_accuracy: 0.4728
# Epoch 29/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6609 - accuracy: 0.4085 - val_loss: 1.5125 - val_accuracy: 0.4694
# Epoch 30/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6579 - accuracy: 0.4076 - val_loss: 1.5073 - val_accuracy: 0.4712
# Epoch 31/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6521 - accuracy: 0.4117 - val_loss: 1.5072 - val_accuracy: 0.4650
# Epoch 32/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6493 - accuracy: 0.4148 - val_loss: 1.4962 - val_accuracy: 0.4664
# Epoch 33/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6589 - accuracy: 0.4095 - val_loss: 1.5236 - val_accuracy: 0.4688
# Epoch 34/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6525 - accuracy: 0.4107 - val_loss: 1.5222 - val_accuracy: 0.4674
# Epoch 35/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6575 - accuracy: 0.4107 - val_loss: 1.5059 - val_accuracy: 0.4696
# Epoch 36/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6511 - accuracy: 0.4124 - val_loss: 1.5111 - val_accuracy: 0.4760
# Epoch 37/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6471 - accuracy: 0.4141 - val_loss: 1.5098 - val_accuracy: 0.4674
# Epoch 38/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6468 - accuracy: 0.4135 - val_loss: 1.4767 - val_accuracy: 0.4816
# Epoch 39/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6368 - accuracy: 0.4135 - val_loss: 1.5009 - val_accuracy: 0.4704
# Epoch 40/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6391 - accuracy: 0.4154 - val_loss: 1.5144 - val_accuracy: 0.4604
# Epoch 41/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6421 - accuracy: 0.4148 - val_loss: 1.6248 - val_accuracy: 0.4254
# Epoch 42/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6359 - accuracy: 0.4200 - val_loss: 1.5077 - val_accuracy: 0.4658
# Epoch 43/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6409 - accuracy: 0.4157 - val_loss: 1.4987 - val_accuracy: 0.4752
# Epoch 44/200
# 1407/1407 [==============================] - 12s 9ms/step - loss: 1.6299 - accuracy: 0.4182 - val_loss: 1.5349 - val_accuracy: 0.4628
# Epoch 45/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6368 - accuracy: 0.4136 - val_loss: 1.5364 - val_accuracy: 0.4622
# Epoch 46/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6254 - accuracy: 0.4214 - val_loss: 1.4705 - val_accuracy: 0.4792
# Epoch 47/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6285 - accuracy: 0.4208 - val_loss: 1.5141 - val_accuracy: 0.4676
# Epoch 48/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6273 - accuracy: 0.4183 - val_loss: 1.4994 - val_accuracy: 0.4724
# Epoch 49/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6319 - accuracy: 0.4207 - val_loss: 1.4823 - val_accuracy: 0.4786
# Epoch 50/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6238 - accuracy: 0.4227 - val_loss: 1.4808 - val_accuracy: 0.4788
# Epoch 51/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6216 - accuracy: 0.4226 - val_loss: 1.4862 - val_accuracy: 0.4742
# Epoch 52/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6135 - accuracy: 0.4261 - val_loss: 1.4968 - val_accuracy: 0.4688
# Epoch 53/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6079 - accuracy: 0.4271 - val_loss: 1.4884 - val_accuracy: 0.4770
# Epoch 54/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6022 - accuracy: 0.4338 - val_loss: 1.4542 - val_accuracy: 0.4886
# Epoch 55/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6089 - accuracy: 0.4290 - val_loss: 1.4548 - val_accuracy: 0.4866
# Epoch 56/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6012 - accuracy: 0.4291 - val_loss: 1.5326 - val_accuracy: 0.4726
# Epoch 57/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6043 - accuracy: 0.4314 - val_loss: 1.5352 - val_accuracy: 0.4554
# Epoch 58/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6179 - accuracy: 0.4247 - val_loss: 1.4746 - val_accuracy: 0.4836
# Epoch 59/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6178 - accuracy: 0.4282 - val_loss: 1.5041 - val_accuracy: 0.4622
# Epoch 60/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6104 - accuracy: 0.4279 - val_loss: 1.4493 - val_accuracy: 0.4844
# Epoch 61/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6051 - accuracy: 0.4287 - val_loss: 1.4532 - val_accuracy: 0.4820
# Epoch 62/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6035 - accuracy: 0.4313 - val_loss: 1.5006 - val_accuracy: 0.4742
# Epoch 63/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5931 - accuracy: 0.4352 - val_loss: 1.4776 - val_accuracy: 0.4798
# Epoch 64/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6063 - accuracy: 0.4331 - val_loss: 1.4667 - val_accuracy: 0.4926
# Epoch 65/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6051 - accuracy: 0.4288 - val_loss: 1.4699 - val_accuracy: 0.4812
# Epoch 66/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6147 - accuracy: 0.4261 - val_loss: 1.4955 - val_accuracy: 0.4704
# Epoch 67/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6076 - accuracy: 0.4297 - val_loss: 1.4679 - val_accuracy: 0.4890
# Epoch 68/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5975 - accuracy: 0.4321 - val_loss: 1.4687 - val_accuracy: 0.4784
# Epoch 69/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6044 - accuracy: 0.4301 - val_loss: 1.4415 - val_accuracy: 0.4936
# Epoch 70/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.5924 - accuracy: 0.4366 - val_loss: 1.4476 - val_accuracy: 0.4894
# Epoch 71/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.5869 - accuracy: 0.4371 - val_loss: 1.4442 - val_accuracy: 0.4896
# Epoch 72/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5896 - accuracy: 0.4361 - val_loss: 1.4847 - val_accuracy: 0.4696
# Epoch 73/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5816 - accuracy: 0.4398 - val_loss: 1.4412 - val_accuracy: 0.4962
# Epoch 74/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5863 - accuracy: 0.4395 - val_loss: 1.4814 - val_accuracy: 0.4826
# Epoch 75/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5786 - accuracy: 0.4387 - val_loss: 1.4262 - val_accuracy: 0.4932
# Epoch 76/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5836 - accuracy: 0.4360 - val_loss: 1.4425 - val_accuracy: 0.4946
# Epoch 77/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6058 - accuracy: 0.4288 - val_loss: 1.5012 - val_accuracy: 0.4706
# Epoch 78/200
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.6048 - accuracy: 0.4298 - val_loss: 1.4526 - val_accuracy: 0.4886
# Epoch 79/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6113 - accuracy: 0.4303 - val_loss: 1.4638 - val_accuracy: 0.4870
# Epoch 80/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6158 - accuracy: 0.4258 - val_loss: 1.4665 - val_accuracy: 0.4870
# Epoch 81/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6012 - accuracy: 0.4287 - val_loss: 1.4503 - val_accuracy: 0.4918
# Epoch 82/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5996 - accuracy: 0.4321 - val_loss: 1.4493 - val_accuracy: 0.4928
# Epoch 83/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5979 - accuracy: 0.4332 - val_loss: 1.4560 - val_accuracy: 0.4850
# Epoch 84/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5975 - accuracy: 0.4311 - val_loss: 1.4443 - val_accuracy: 0.4852
# Epoch 85/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5958 - accuracy: 0.4336 - val_loss: 1.4448 - val_accuracy: 0.4958
# Epoch 86/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5873 - accuracy: 0.4374 - val_loss: 1.4405 - val_accuracy: 0.4922
# Epoch 87/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5945 - accuracy: 0.4330 - val_loss: 1.4469 - val_accuracy: 0.4928
# Epoch 88/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6034 - accuracy: 0.4293 - val_loss: 1.4370 - val_accuracy: 0.5000
# Epoch 89/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.5981 - accuracy: 0.4303 - val_loss: 1.4741 - val_accuracy: 0.4872
# Epoch 90/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6050 - accuracy: 0.4289 - val_loss: 1.4699 - val_accuracy: 0.4846
# Epoch 91/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6077 - accuracy: 0.4284 - val_loss: 1.4578 - val_accuracy: 0.4844
# Epoch 92/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6070 - accuracy: 0.4257 - val_loss: 1.4688 - val_accuracy: 0.4932
# Epoch 93/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6141 - accuracy: 0.4263 - val_loss: 1.4498 - val_accuracy: 0.4888
# Epoch 94/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6040 - accuracy: 0.4307 - val_loss: 1.4440 - val_accuracy: 0.4906
# Epoch 95/200
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6011 - accuracy: 0.4332 - val_loss: 1.4541 - val_accuracy: 0.4792
# Elapsed time is 1096.587118 seconds.

# %% [markdown]
# **Check testing accuracy**

# %%
C_MLP.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4468 - accuracy: 0.4804
# [1.446766972541809, 0.4803999960422516]

# %% [markdown]
# **Plot training and validation loss**

# %%
filename = 'Training history CIFAR10 [MLP]'+'.png'
plot_fitting_history(history_C_MLP, filename, dpi = 100)

# %% [markdown]
# **Report classification performance & plot confusion matrix**

# %%
y_pred = C_MLP.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]
classification_results(X_test,y_test,y_pred_classes)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.47      0.53      1000
#            1       0.63      0.54      0.58      1000
#            2       0.40      0.31      0.35      1000
#            3       0.33      0.27      0.29      1000
#            4       0.49      0.34      0.40      1000
#            5       0.47      0.30      0.37      1000
#            6       0.37      0.76      0.50      1000
#            7       0.58      0.52      0.55      1000
#            8       0.52      0.71      0.60      1000
#            9       0.53      0.58      0.55      1000
#
#     accuracy                           0.48     10000
#    macro avg       0.49      0.48      0.47     10000
# weighted avg       0.49      0.48      0.47     10000

# %%
C_MLP.save('MLP_CIFAR10.h5')

# %%
from keras.models import load_model
MLP_CIFAR10 = load_model('MLP_CIFAR10.h5')

# %%
MLP_CIFAR10.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4468 - accuracy: 0.4804
# [1.446766972541809, 0.4803999960422516]
