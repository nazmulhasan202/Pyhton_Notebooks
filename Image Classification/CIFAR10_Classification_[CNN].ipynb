# %% [markdown]
# **Import packages**

# %%
# !pip install pytictoc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytictoc
#   Downloading pytictoc-1.5.2-py2.py3-none-any.whl (4.0 kB)
# Installing collected packages: pytictoc
# Successfully installed pytictoc-1.5.2

# %%
import random
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pytictoc import TicToc
from sklearn.model_selection import train_test_split
warnings.filterwarnings( "ignore" )

# %% [markdown]
# **Load the dataset**

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# ((50000, 32, 32, 3), (50000,), (10000, 32, 32, 3), (10000,))

# %% [markdown]
# **Create helper functions**

# %%
def plot_sample_image(X, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(X[index])
    classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
    plt.xlabel('Image Label: {}'.format(classes[y[index]]))

def classification_results(X_test,y_test,y_pred_classes):
  from sklearn.metrics import confusion_matrix , classification_report
  import seaborn as sn

  cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_classes)
  plt.figure(figsize = (7,5))
  sn.heatmap(cm, annot=True, fmt='d', cmap='Greens')
  plt.xlabel('Predicted');
  plt.ylabel('Truth');

  print("Classification Report: \n", classification_report(y_test, y_pred_classes))

def plot_fitting_history(history,filename,dpi):
  epochs = len(history.history['loss'])
  epoch_data = np.arange(1,epochs+1)
  plt.plot(epoch_data,history.history['loss'],'o-')
  plt.ylabel('Loss')
  plt.xlabel('Epoch sequence' )
  if epochs <= 60: plt.xticks(np.arange(0, epochs + 1, step=5))
  else: plt.xticks(np.arange(0, epochs + 1, step=20))
  if 'val_loss' in history.history.keys():
    plt.plot(epoch_data,history.history['val_loss'],'o--')
    plt.legend(['Training','Validation'])
  else:
    plt.legend(['Training'])
  plt.savefig(filename, dpi=dpi)
  plt.show()

# %% [markdown]
# **Plot sample image**

# %%
plot_sample_image(X_train, y_train, np.random.randint(100))

# %% [markdown]
# # CNN (convolutional neuaral network) Classifier

# %%
import random
import tensorflow as tf
seed = 42
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# Network architecture
C_CNN = models.Sequential([

    layers.Conv2D(128, (3, 3), padding='same', input_shape=(32, 32, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    layers.Flatten(),

    layers.Dense(2048, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(1024, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(256, activation='relu'), 
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax'),
])

C_CNN.summary()

# Data Augmentation
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1,
                                                    random_state=42, stratify=y_train)

from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    channel_shift_range=50,
    horizontal_flip=True)
datagen.fit(X_train)

# validationgen = ImageDataGenerator(
#     rescale=1./255)
# validationgen.fit(X_val)
X_val = X_val/255.0

# Compilation
learning_rate =  0.0001
C_CNN.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# Training
t_CNN = TicToc()
t_CNN.tic()
early_callbacks = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
history_C_CNN = C_CNN.fit(datagen.flow(X_train, y_train, batch_size=32), 
                          steps_per_epoch=len(X_train) / 32, epochs=200,
                          validation_data=(X_val, y_val), callbacks = early_callbacks, verbose=1)

t_CNN.toc()

print(f"\n\nMaximum Validation Accuracy: {round(np.max(history_C_CNN.history['val_accuracy'])*100,2)}%")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  batch_normalization_12 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 30, 30, 128)      512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_9 (Dropout)         (None, 15, 15, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 128)       147584
#
#  batch_normalization_14 (Bat  (None, 15, 15, 128)      512
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 128)       147584
#
#  batch_normalization_15 (Bat  (None, 13, 13, 128)      512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_10 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 128)         147584
#
#  batch_normalization_16 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 128)         147584
#
#  batch_normalization_17 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout_11 (Dropout)        (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 2048)              1050624
#
#  batch_normalization_18 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 2048)              0
#
#  dense_8 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_19 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  batch_normalization_20 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  batch_normalization_21 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_22 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  batch_normalization_23 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 4,634,890
# Trainable params: 4,624,906
# Non-trainable params: 9,984
# _________________________________________________________________
# Epoch 1/200
# 1406/1406 [==============================] - 59s 35ms/step - loss: 3.1992 - accuracy: 0.1134 - val_loss: 2.1029 - val_accuracy: 0.1918
# Epoch 2/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 2.6088 - accuracy: 0.1524 - val_loss: 1.9883 - val_accuracy: 0.2192
# Epoch 3/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 2.3283 - accuracy: 0.1757 - val_loss: 1.8502 - val_accuracy: 0.2818
# Epoch 4/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 2.1461 - accuracy: 0.2002 - val_loss: 1.8092 - val_accuracy: 0.2950
# Epoch 5/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 2.0118 - accuracy: 0.2322 - val_loss: 1.6884 - val_accuracy: 0.3364
# Epoch 6/200
# 1406/1406 [==============================] - 49s 35ms/step - loss: 1.9025 - accuracy: 0.2636 - val_loss: 1.6154 - val_accuracy: 0.3668
# Epoch 7/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 1.7941 - accuracy: 0.3074 - val_loss: 1.6447 - val_accuracy: 0.3736
# Epoch 8/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.6952 - accuracy: 0.3518 - val_loss: 1.4908 - val_accuracy: 0.4468
# Epoch 9/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 1.6176 - accuracy: 0.3898 - val_loss: 1.3828 - val_accuracy: 0.4852
# Epoch 10/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 1.5325 - accuracy: 0.4300 - val_loss: 1.3235 - val_accuracy: 0.5340
# Epoch 11/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 1.4403 - accuracy: 0.4786 - val_loss: 1.1522 - val_accuracy: 0.5872
# Epoch 12/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.3676 - accuracy: 0.5146 - val_loss: 1.2098 - val_accuracy: 0.5702
# Epoch 13/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.2975 - accuracy: 0.5482 - val_loss: 1.1240 - val_accuracy: 0.6082
# Epoch 14/200
# 1406/1406 [==============================] - 52s 37ms/step - loss: 1.2451 - accuracy: 0.5698 - val_loss: 1.0410 - val_accuracy: 0.6364
# Epoch 15/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.2009 - accuracy: 0.5915 - val_loss: 1.0477 - val_accuracy: 0.6322
# Epoch 16/200
# 1406/1406 [==============================] - 52s 37ms/step - loss: 1.1570 - accuracy: 0.6058 - val_loss: 0.8479 - val_accuracy: 0.7068
# Epoch 17/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.1211 - accuracy: 0.6215 - val_loss: 0.9130 - val_accuracy: 0.6896
# Epoch 18/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.0856 - accuracy: 0.6342 - val_loss: 0.8931 - val_accuracy: 0.6938
# Epoch 19/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.0622 - accuracy: 0.6431 - val_loss: 0.8748 - val_accuracy: 0.6994
# Epoch 20/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.0435 - accuracy: 0.6556 - val_loss: 0.7890 - val_accuracy: 0.7230
# Epoch 21/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 1.0216 - accuracy: 0.6590 - val_loss: 0.8442 - val_accuracy: 0.7082
# Epoch 22/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.9943 - accuracy: 0.6668 - val_loss: 0.7681 - val_accuracy: 0.7400
# Epoch 23/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.9704 - accuracy: 0.6766 - val_loss: 0.7194 - val_accuracy: 0.7542
# Epoch 24/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.9465 - accuracy: 0.6856 - val_loss: 0.7368 - val_accuracy: 0.7468
# Epoch 25/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.9405 - accuracy: 0.6902 - val_loss: 0.7649 - val_accuracy: 0.7432
# Epoch 26/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.9159 - accuracy: 0.6966 - val_loss: 0.6878 - val_accuracy: 0.7628
# Epoch 27/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.9020 - accuracy: 0.7037 - val_loss: 0.6939 - val_accuracy: 0.7682
# Epoch 28/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.8874 - accuracy: 0.7119 - val_loss: 0.6344 - val_accuracy: 0.7848
# Epoch 29/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.8671 - accuracy: 0.7176 - val_loss: 0.7117 - val_accuracy: 0.7584
# Epoch 30/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.8564 - accuracy: 0.7203 - val_loss: 0.6307 - val_accuracy: 0.7886
# Epoch 31/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.8416 - accuracy: 0.7248 - val_loss: 0.6172 - val_accuracy: 0.7880
# Epoch 32/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.8323 - accuracy: 0.7274 - val_loss: 0.6067 - val_accuracy: 0.7920
# Epoch 33/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.8261 - accuracy: 0.7349 - val_loss: 0.5921 - val_accuracy: 0.7996
# Epoch 34/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.8092 - accuracy: 0.7344 - val_loss: 0.6109 - val_accuracy: 0.7926
# Epoch 35/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.7925 - accuracy: 0.7429 - val_loss: 0.5521 - val_accuracy: 0.8170
# Epoch 36/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.7839 - accuracy: 0.7470 - val_loss: 0.5431 - val_accuracy: 0.8150
# Epoch 37/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.7795 - accuracy: 0.7476 - val_loss: 0.5836 - val_accuracy: 0.8038
# Epoch 38/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.7682 - accuracy: 0.7517 - val_loss: 0.6145 - val_accuracy: 0.7984
# Epoch 39/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.7691 - accuracy: 0.7530 - val_loss: 0.5312 - val_accuracy: 0.8272
# Epoch 40/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.7440 - accuracy: 0.7606 - val_loss: 0.5121 - val_accuracy: 0.8298
# Epoch 41/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.7393 - accuracy: 0.7625 - val_loss: 0.6013 - val_accuracy: 0.7962
# Epoch 42/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.7388 - accuracy: 0.7644 - val_loss: 0.5427 - val_accuracy: 0.8212
# Epoch 43/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.7349 - accuracy: 0.7639 - val_loss: 0.5263 - val_accuracy: 0.8238
# Epoch 44/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.7226 - accuracy: 0.7687 - val_loss: 0.4745 - val_accuracy: 0.8416
# Epoch 45/200
# 1406/1406 [==============================] - 49s 35ms/step - loss: 0.7192 - accuracy: 0.7690 - val_loss: 0.5045 - val_accuracy: 0.8304
# Epoch 46/200
# 1406/1406 [==============================] - 50s 35ms/step - loss: 0.7060 - accuracy: 0.7736 - val_loss: 0.5507 - val_accuracy: 0.8174
# Epoch 47/200
# 1406/1406 [==============================] - 49s 35ms/step - loss: 0.6994 - accuracy: 0.7750 - val_loss: 0.4862 - val_accuracy: 0.8326
# Epoch 48/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.6932 - accuracy: 0.7788 - val_loss: 0.4924 - val_accuracy: 0.8296
# Epoch 49/200
# 1406/1406 [==============================] - 52s 37ms/step - loss: 0.6850 - accuracy: 0.7804 - val_loss: 0.4998 - val_accuracy: 0.8294
# Epoch 50/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.6799 - accuracy: 0.7826 - val_loss: 0.6004 - val_accuracy: 0.8002
# Epoch 51/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0
200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.4516 - accuracy: 0.8550 - val_loss: 0.3411 - val_accuracy: 0.8788
# Epoch 127/200
# 1406/1406 [==============================] - 50s 36ms/step - loss: 0.4602 - accuracy: 0.8551 - val_loss: 0.3618 - val_accuracy: 0.8756
# Epoch 128/200
# 1406/1406 [==============================] - 54s 39ms/step - loss: 0.4529 - accuracy: 0.8568 - val_loss: 0.3501 - val_accuracy: 0.8844
# Epoch 129/200
# 1406/1406 [==============================] - 58s 42ms/step - loss: 0.4497 - accuracy: 0.8582 - val_loss: 0.3585 - val_accuracy: 0.8756
# Epoch 130/200
# 1406/1406 [==============================] - 54s 39ms/step - loss: 0.4552 - accuracy: 0.8577 - val_loss: 0.3749 - val_accuracy: 0.8752
# Epoch 131/200
# 1406/1406 [==============================] - 52s 37ms/step - loss: 0.4511 - accuracy: 0.8577 - val_loss: 0.3403 - val_accuracy: 0.8878
# Epoch 132/200
# 1406/1406 [==============================] - 55s 39ms/step - loss: 0.4525 - accuracy: 0.8571 - val_loss: 0.3719 - val_accuracy: 0.8758
# Epoch 133/200
# 1406/1406 [==============================] - 54s 38ms/step - loss: 0.4483 - accuracy: 0.8605 - val_loss: 0.3432 - val_accuracy: 0.8846
# Epoch 134/200
# 1406/1406 [==============================] - 54s 38ms/step - loss: 0.4478 - accuracy: 0.8587 - val_loss: 0.3439 - val_accuracy: 0.8836
# Epoch 135/200
# 1406/1406 [==============================] - 51s 36ms/step - loss: 0.4470 - accuracy: 0.8585 - val_loss: 0.3763 - val_accuracy: 0.8758
# Elapsed time is 7411.345526 seconds.
#
#
# Maximum Validation Accuracy: 88.78%

# %% [markdown]
# **Check testing accuracy**

# %%
(_, _), (X_test,y_test) = datasets.cifar10.load_data()
X_test = X_test/255.0
y_test = y_test.reshape(-1,)
C_CNN.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3970 - accuracy: 0.8739
# [0.39703214168548584, 0.8738999962806702]

# %% [markdown]
# **Plot training and validation loss**

# %%
filename = 'Training history CIFAR10 [CNN]'+'.png'
plot_fitting_history(history_C_CNN, filename, dpi = 100)

# %% [markdown]
# **Report classification performance & plot confusion matrix**

# %%
y_pred = C_CNN.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]
classification_results(X_test,y_test,y_pred_classes)
# Out:
# 313/313 [==============================] - 2s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      1000
#            1       0.91      0.96      0.94      1000
#            2       0.85      0.83      0.84      1000
#            3       0.82      0.70      0.76      1000
#            4       0.87      0.91      0.89      1000
#            5       0.93      0.68      0.78      1000
#            6       0.81      0.97      0.88      1000
#            7       0.89      0.93      0.91      1000
#            8       0.93      0.92      0.92      1000
#            9       0.86      0.94      0.90      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.88      0.87      0.87     10000
# weighted avg       0.88      0.87      0.87     10000

# %% [markdown]
# **Save the trained model**

# %%
C_CNN.save('CNN_CIFAR10.h5')

# %% [markdown]
# **Load the saved model**

# %%
from keras.models import load_model
CNN_CIFAR10 = load_model('CNN_CIFAR10.h5')

# %%
CNN_CIFAR10.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3970 - accuracy: 0.8739
# [0.39703214168548584, 0.8738999962806702]
